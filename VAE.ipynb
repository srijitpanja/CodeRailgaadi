# %%
# !git clone https://github.com/alexeyev/Keras-Generating-Sentences-from-a-Continuous-Space.git
# Out:
# Cloning into 'Keras-Generating-Sentences-from-a-Continuous-Space'...
# remote: Enumerating objects: 20, done.
# remote: Total 20 (delta 0), reused 0 (delta 0), pack-reused 20
# Unpacking objects: 100% (20/20), done.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
drive.mount("/content/drive", force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/Keras-Generating-Sentences-from-a-Continuous-Space/fra-eng.zip
# Out:
# Archive:  /content/Keras-Generating-Sentences-from-a-Continuous-Space/fra-eng.zip
#   inflating: _about.txt
#   inflating: fra.txt

# %%
# !python /content/Keras-Generating-Sentences-from-a-Continuous-Space/lstm_vae/inference.py

# %%
# !python /content/Keras-Generating-Sentences-from-a-Continuous-Space/lstm_vae/lstm_vae.py
# Out:
# 2021-02-08 19:46:41.128918: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1

# %%
# !python /content/Keras-Generating-Sentences-from-a-Continuous-Space/lstm_vae/word_vectors.py

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# !python /content/Keras-Generating-Sentences-from-a-Continuous-Space/run.py
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
# !pip install numpy==1.16.4
# Out:
# ...
#      |████████████████████████████████| 17.3MB 235kB/s
# ERROR: umap-learn 0.5.0 has requirement numpy>=1.17, but you'll have numpy 1.16.4 which is incompatible.
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# ...
#   Found existing installation: numpy 1.19.5
#     Uninstalling numpy-1.19.5:
#       Successfully uninstalled numpy-1.19.5
# ...

# %%
import numpy as np
np.__version__
# Out:
# '1.19.5'

# %%
# !pip install keras==2.0.8
# Out:
# ...
#      |████████████████████████████████| 276kB 8.7MB/s
# ...
# ERROR: textgenrnn 1.4.1 has requirement keras>=2.1.5, but you'll have keras 2.0.8 which is incompatible.
# ...
#   Found existing installation: Keras 2.4.3
#     Uninstalling Keras-2.4.3:
#       Successfully uninstalled Keras-2.4.3
# ...

# %%
import keras
keras.__version__
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
# !pip install tensorflow==1.14
# Out:
# ...
#      |████████████████████████████████| 109.3MB 65kB/s
# ...
#      |████████████████████████████████| 51kB 8.3MB/s
# ...
#      |████████████████████████████████| 491kB 52.9MB/s
# ...
#      |████████████████████████████████| 3.2MB 54.8MB/s
# ...
#   Found existing installation: tensorflow-estimator 2.4.0
#     Uninstalling tensorflow-estimator-2.4.0:
#       Successfully uninstalled tensorflow-estimator-2.4.0
#   Found existing installation: tensorboard 2.4.1
#     Uninstalling tensorboard-2.4.1:
#       Successfully uninstalled tensorboard-2.4.1
#   Found existing installation: tensorflow 2.4.1
#     Uninstalling tensorflow-2.4.1:
#       Successfully uninstalled tensorflow-2.4.1
# ...

# %%
import tensorflow as tf
tf.__version__
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
from tensorflow.python.compiler.tensorrt import trt_convert as trt

# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()

# %%
text = 'Python: Cut of the last word of a sentence? <end>'
text[:text.rfind(' ')]
#'Python: Cut of the last word of a'
# Out:
# 'Python: Cut of the last word of a sentence?'

# %%
# !git init
# Out:
# Initialized empty Git repository in /content/.git/

# %%
# !git config — global user.email “srijit.panja@nirman.io”
# !git config — global user.name “srijitpanja”
# Out:
# usage: git config [<options>]
#
# Config file location
#     --global              use global config file
#     --system              use system config file
#     --local               use repository config file
#     -f, --file <file>     use given config file
#     --blob <blob-id>      read config from given blob object
#
# Action
#     --get                 get value: name [value-regex]
#     --get-all             get all values: key [value-regex]
#     --get-regexp          get values for regexp: name-regex [value-regex]
#     --get-urlmatch        get value specific for the URL: section[.var] URL
#     --replace-all         replace all matching variables: name value [value_regex]
#     --add                 add a new variable: name value
#     --unset               remove a variable: name [value-regex]
#     --unset-all           remove all matches: name [value-regex]
#     --rename-section      rename section: old-name new-name
# ...

# %%
# !git config --show-origin
# Out:
# usage: git config [<options>]
#
# Config file location
#     --global              use global config file
#     --system              use system config file
#     --local               use repository config file
#     -f, --file <file>     use given config file
#     --blob <blob-id>      read config from given blob object
#
# Action
#     --get                 get value: name [value-regex]
#     --get-all             get all values: key [value-regex]
#     --get-regexp          get values for regexp: name-regex [value-regex]
#     --get-urlmatch        get value specific for the URL: section[.var] URL
#     --replace-all         replace all matching variables: name value [value_regex]
#     --add                 add a new variable: name value
#     --unset               remove a variable: name [value-regex]
#     --unset-all           remove all matches: name [value-regex]
#     --rename-section      rename section: old-name new-name
# ...
